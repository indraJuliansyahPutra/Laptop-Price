# %%
import pandas as pd
import numpy as np

# %%
laptop = pd.read_csv('laptops_train.csv')

laptop.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight        Price
# 0                      NaN  1.37kg  11912523.48
# 1                      NaN  1.34kg   7993374.48
# 2                      NaN  1.86kg   5112900.00
# 3                      NaN  1.83kg  22563005.40
# 4                      NaN  1.37kg  16037611.20

# %%
laptop = laptop.rename(columns=str.lower)

laptop = laptop.rename(columns={" storage": "storage"})

laptop.columns
# Out:
# Index(['manufacturer', 'model name', 'category', 'screen size', 'screen',
#        'cpu', 'ram', 'storage', 'gpu', 'operating system',
#        'operating system version', 'weight', 'price'],
#       dtype='object')

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   manufacturer              977 non-null    object
#  1   model name                977 non-null    object
#  2   category                  977 non-null    object
#  3   screen size               977 non-null    object
#  4   screen                    977 non-null    object
#  5   cpu                       977 non-null    object
#  6   ram                       977 non-null    object
#  7   storage                   977 non-null    object
#  8   gpu                       977 non-null    object
#  9   operating system          977 non-null    object
#  10  operating system version  841 non-null    object
#  11  weight                    977 non-null    object
#  12  price                     977 non-null    float64
# dtypes: float64(1), object(12)
# memory usage: 99.4+ KB

# %%
laptop['screen size'] = laptop['screen size'].str.replace('"', '')

laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                                  screen                          cpu   ram  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                              1440x900         Intel Core i5 1.8GHz   8GB
# 2                     Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 3    IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16GB
# 4    IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz   8GB
# ..                                  ...                          ...   ...
# 972                   Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  32GB
# 973                   Full HD 1920x1080   Intel Core i5 6200U 2.3GHz   8GB
# 974                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 975         IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.70GHz   8GB
# 976                            1366x768   Intel Core i5 6200U 2.3GHz   4GB
#
#                   storage                           gpu operating system  \
# 0               128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1     128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2               256GB SSD         Intel HD Graphics 620            No OS
# 3               512GB SSD            AMD Radeon Pro 455            macOS
# 4               256GB SSD  Intel Iris Plus Graphics 650            macOS
# ..                    ...                           ...              ...
# 972  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1070          Windows
# 973             256GB SSD         Intel HD Graphics 520          Windows
# 974  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1060          Windows
# 975  128GB SSD +  1TB HDD          Nvidia GeForce 930MX          Windows
# 976          508GB Hybrid         Intel HD Graphics 520          Windows
#
#     operating system version  weight        price
# 0                        NaN  1.37kg  11912523.48
# 1                        NaN  1.34kg   7993374.48
# 2                        NaN  1.86kg   5112900.00
# 3                        NaN  1.83kg  22563005.40
# 4                        NaN  1.37kg  16037611.20
# ..                       ...     ...          ...
# 972                       10  4.42kg  24897600.00
# 973                       10  1.95kg  10492560.00
# 974                       10  2.73kg  18227710.80
# 975                       10  2.04kg   8705268.00
# 976                        7  1.70kg   8909784.00
#
# [977 rows x 13 columns]

# %%
laptop['screen'].value_counts()
# Out:
# Full HD 1920x1080                                397
# IPS Panel Full HD 1920x1080                      181
# 1366x768                                         180
# Full HD / Touchscreen 1920x1080                   38
# IPS Panel Full HD / Touchscreen 1920x1080         35
# 1600x900                                          19
# Touchscreen 1366x768                              15
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# IPS Panel 4K Ultra HD 3840x2160                   10
# 4K Ultra HD / Touchscreen 3840x2160                9
# Quad HD+ / Touchscreen 3200x1800                   8
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# Touchscreen 2560x1440                              5
# 4K Ultra HD 3840x2160                              5
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                3
# IPS Panel Quad HD+ / Touchscreen 3200x1800         3
# IPS Panel Quad HD+ 2560x1440                       3
# Touchscreen 2400x1600                              3
# IPS Panel Touchscreen 1366x768                     3
# 1920x1080                                          3
# IPS Panel Retina Display 2304x1440                 3
# 2560x1440                                          2
# IPS Panel Quad HD+ 3200x1800                       2
# IPS Panel Full HD 2160x1440                        2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      1
# IPS Panel Full HD 1920x1200                        1
# Touchscreen / Full HD 1920x1080                    1
# IPS Panel Touchscreen 2560x1440                    1
# IPS Panel Retina Display 2736x1824                 1
# IPS Panel Touchscreen 1920x1200                    1
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# Quad HD+ 3200x1800                                 1
# Name: screen, dtype: int64

# %%
laptop['resolution'] = laptop['screen'].str.extract(r'(\d+x\d+)')
laptop['resolution']
# Out:
# 0      2560x1600
# 1       1440x900
# 2      1920x1080
# 3      2880x1800
# 4      2560x1600
#          ...
# 972    1920x1080
# 973    1920x1080
# 974    1920x1080
# 975    1920x1080
# 976     1366x768
# Name: resolution, Length: 977, dtype: object

# %%
laptop['screentype'] = laptop['screen'].replace(r'(\d+x\d+)', '', regex=True)
laptop['screentype'] = laptop['screentype'].replace(r'Full HD|Quad HD|Quad HD|\+|/|4K Ultra HD', "", regex=True)
laptop['screentype']
# Out:
# 0      IPS Panel Retina Display
# 1
# 2
# 3      IPS Panel Retina Display
# 4      IPS Panel Retina Display
#                  ...
# 972
# 973
# 974
# 975                  IPS Panel
# 976
# Name: screentype, Length: 977, dtype: object

# %%
laptop['touchscreen'] = laptop['screentype'].str.extract(r'(Touchscreen)')
laptop['screentype'] = laptop['screentype'].replace(r'(Touchscreen)', "", regex=True)
laptop['touchscreen']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 972    NaN
# 973    NaN
# 974    NaN
# 975    NaN
# 976    NaN
# Name: touchscreen, Length: 977, dtype: object

# %%
laptop['screentype'] = laptop['screentype'].replace(r' ', "", regex=True)
laptop['screentype'].value_counts()
# Out:
#                          697
# IPSPanel                 266
# IPSPanelRetinaDisplay     14
# Name: screentype, dtype: int64

# %%
laptop['screentype'] = laptop['screentype'].replace(r'^\s*$', np.nan, regex=True)
laptop['screentype'].value_counts()
# Out:
# IPSPanel                 266
# IPSPanelRetinaDisplay     14
# Name: screentype, dtype: int64

# %%
laptop['touchscreen'] = laptop['touchscreen'].replace('Touchscreen', 1.0)
laptop['touchscreen'] = laptop['touchscreen'].replace(np.nan, 0)
laptop['touchscreen'].value_counts()
# Out:
# 0.0    836
# 1.0    141
# Name: touchscreen, dtype: int64

# %%
laptop['resolution'].value_counts()
# Out:
# 1920x1080    655
# 1366x768     206
# 3840x2160     36
# 1600x900      19
# 3200x1800     15
# 2560x1440     15
# 2560x1600      6
# 2256x1504      6
# 1440x900       4
# 2880x1800      4
# 2304x1440      3
# 2400x1600      3
# 1920x1200      2
# 2160x1440      2
# 2736x1824      1
# Name: resolution, dtype: int64

# %%
laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                                  screen                          cpu   ram  \
# 0    IPS Panel Retina Display 2560x1600         Intel Core i5 2.3GHz   8GB
# 1                              1440x900         Intel Core i5 1.8GHz   8GB
# 2                     Full HD 1920x1080   Intel Core i5 7200U 2.5GHz   8GB
# 3    IPS Panel Retina Display 2880x1800         Intel Core i7 2.7GHz  16GB
# 4    IPS Panel Retina Display 2560x1600         Intel Core i5 3.1GHz   8GB
# ..                                  ...                          ...   ...
# 972                   Full HD 1920x1080  Intel Core i7 6700HQ 2.6GHz  32GB
# 973                   Full HD 1920x1080   Intel Core i5 6200U 2.3GHz   8GB
# 974                   Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz  16GB
# 975         IPS Panel Full HD 1920x1080  Intel Core i5 7200U 2.70GHz   8GB
# 976                            1366x768   Intel Core i5 6200U 2.3GHz   4GB
#
#                   storage                           gpu operating system  \
# 0               128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1     128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2               256GB SSD         Intel HD Graphics 620            No OS
# 3               512GB SSD            AMD Radeon Pro 455            macOS
# 4               256GB SSD  Intel Iris Plus Graphics 650            macOS
# ..                    ...                           ...              ...
# 972  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1070          Windows
# 973             256GB SSD         Intel HD Graphics 520          Windows
# 974  256GB SSD +  1TB HDD       Nvidia GeForce GTX 1060          Windows
# 975  128GB SSD +  1TB HDD          Nvidia GeForce 930MX          Windows
# 976          508GB Hybrid         Intel HD Graphics 520          Windows
#
#     operating system version  weight        price resolution  \
# 0                        NaN  1.37kg  11912523.48  2560x1600
# 1                        NaN  1.34kg   7993374.48   1440x900
# 2                        NaN  1.86kg   5112900.00  1920x1080
# 3                        NaN  1.83kg  22563005.40  2880x1800
# 4                        NaN  1.37kg  16037611.20  2560x1600
# ..                       ...     ...          ...        ...
# 972                       10  4.42kg  24897600.00  1920x1080
# 973                       10  1.95kg  10492560.00  1920x1080
# 974                       10  2.73kg  18227710.80  1920x1080
# 975                       10  2.04kg   8705268.00  1920x1080
# 976                        7  1.70kg   8909784.00   1366x768
#
#                 screentype  touchscreen
# 0    IPSPanelRetinaDisplay          0.0
# 1                      NaN          0.0
# 2                      NaN          0.0
# 3    IPSPanelRetinaDisplay          0.0
# 4    IPSPanelRetinaDisplay          0.0
# ..                     ...          ...
# 972                    NaN          0.0
# 973                    NaN          0.0
# 974                    NaN          0.0
# 975               IPSPanel          0.0
# 976                    NaN          0.0
#
# [977 rows x 16 columns]

# %%
laptop = laptop.drop('screen', axis=1)

laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu   ram               storage  \
# 0           Intel Core i5 2.3GHz   8GB             128GB SSD
# 1           Intel Core i5 1.8GHz   8GB   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 3           Intel Core i7 2.7GHz  16GB             512GB SSD
# 4           Intel Core i5 3.1GHz   8GB             256GB SSD
# ..                           ...   ...                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32GB  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8GB  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4GB          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      weight        price resolution             screentype  touchscreen
# 0    1.37kg  11912523.48  2560x1600  IPSPanelRetinaDisplay          0.0
# 1    1.34kg   7993374.48   1440x900                    NaN          0.0
# 2    1.86kg   5112900.00  1920x1080                    NaN          0.0
# 3    1.83kg  22563005.40  2880x1800  IPSPanelRetinaDisplay          0.0
# 4    1.37kg  16037611.20  2560x1600  IPSPanelRetinaDisplay          0.0
# ..      ...          ...        ...                    ...          ...
# 972  4.42kg  24897600.00  1920x1080                    NaN          0.0
# 973  1.95kg  10492560.00  1920x1080                    NaN          0.0
# 974  2.73kg  18227710.80  1920x1080                    NaN          0.0
# 975  2.04kg   8705268.00  1920x1080               IPSPanel          0.0
# 976  1.70kg   8909784.00   1366x768                    NaN          0.0
#
# [977 rows x 15 columns]

# %%
laptop['cpu']
# Out:
# 0             Intel Core i5 2.3GHz
# 1             Intel Core i5 1.8GHz
# 2       Intel Core i5 7200U 2.5GHz
# 3             Intel Core i7 2.7GHz
# 4             Intel Core i5 3.1GHz
#                   ...
# 972    Intel Core i7 6700HQ 2.6GHz
# 973     Intel Core i5 6200U 2.3GHz
# 974    Intel Core i7 7700HQ 2.8GHz
# 975    Intel Core i5 7200U 2.70GHz
# 976     Intel Core i5 6200U 2.3GHz
# Name: cpu, Length: 977, dtype: object

# %%
laptop['cpu name'] = laptop['cpu'].str.rsplit(' ', n=1).str[0]
laptop['cpu speed'] = laptop['cpu'].str.rsplit(' ', n=1).str[-1]

laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu   ram               storage  \
# 0           Intel Core i5 2.3GHz   8GB             128GB SSD
# 1           Intel Core i5 1.8GHz   8GB   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 3           Intel Core i7 2.7GHz  16GB             512GB SSD
# 4           Intel Core i5 3.1GHz   8GB             256GB SSD
# ..                           ...   ...                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32GB  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8GB  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4GB          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      weight        price resolution             screentype  touchscreen  \
# 0    1.37kg  11912523.48  2560x1600  IPSPanelRetinaDisplay          0.0
# 1    1.34kg   7993374.48   1440x900                    NaN          0.0
# 2    1.86kg   5112900.00  1920x1080                    NaN          0.0
# 3    1.83kg  22563005.40  2880x1800  IPSPanelRetinaDisplay          0.0
# 4    1.37kg  16037611.20  2560x1600  IPSPanelRetinaDisplay          0.0
# ..      ...          ...        ...                    ...          ...
# 972  4.42kg  24897600.00  1920x1080                    NaN          0.0
# 973  1.95kg  10492560.00  1920x1080                    NaN          0.0
# 974  2.73kg  18227710.80  1920x1080                    NaN          0.0
# 975  2.04kg   8705268.00  1920x1080               IPSPanel          0.0
# 976  1.70kg   8909784.00   1366x768                    NaN          0.0
#
#                  cpu name cpu speed
# 0           Intel Core i5    2.3GHz
# 1           Intel Core i5    1.8GHz
# 2     Intel Core i5 7200U    2.5GHz
# 3           Intel Core i7    2.7GHz
# 4           Intel Core i5    3.1GHz
# ..                    ...       ...
# 972  Intel Core i7 6700HQ    2.6GHz
# 973   Intel Core i5 6200U    2.3GHz
# 974  Intel Core i7 7700HQ    2.8GHz
# 975   Intel Core i5 7200U   2.70GHz
# 976   Intel Core i5 6200U    2.3GHz
#
# [977 rows x 17 columns]

# %%
laptop['cpu speed'] = laptop['cpu speed'].str.replace('GHz', '')
laptop['cpu speed'] = laptop['cpu speed'].astype('float')

# %%
laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu   ram               storage  \
# 0           Intel Core i5 2.3GHz   8GB             128GB SSD
# 1           Intel Core i5 1.8GHz   8GB   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 3           Intel Core i7 2.7GHz  16GB             512GB SSD
# 4           Intel Core i5 3.1GHz   8GB             256GB SSD
# ..                           ...   ...                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32GB  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8GB  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4GB          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      weight        price resolution             screentype  touchscreen  \
# 0    1.37kg  11912523.48  2560x1600  IPSPanelRetinaDisplay          0.0
# 1    1.34kg   7993374.48   1440x900                    NaN          0.0
# 2    1.86kg   5112900.00  1920x1080                    NaN          0.0
# 3    1.83kg  22563005.40  2880x1800  IPSPanelRetinaDisplay          0.0
# 4    1.37kg  16037611.20  2560x1600  IPSPanelRetinaDisplay          0.0
# ..      ...          ...        ...                    ...          ...
# 972  4.42kg  24897600.00  1920x1080                    NaN          0.0
# 973  1.95kg  10492560.00  1920x1080                    NaN          0.0
# 974  2.73kg  18227710.80  1920x1080                    NaN          0.0
# 975  2.04kg   8705268.00  1920x1080               IPSPanel          0.0
# 976  1.70kg   8909784.00   1366x768                    NaN          0.0
#
#                  cpu name  cpu speed
# 0           Intel Core i5        2.3
# 1           Intel Core i5        1.8
# 2     Intel Core i5 7200U        2.5
# 3           Intel Core i7        2.7
# 4           Intel Core i5        3.1
# ..                    ...        ...
# 972  Intel Core i7 6700HQ        2.6
# 973   Intel Core i5 6200U        2.3
# 974  Intel Core i7 7700HQ        2.8
# 975   Intel Core i5 7200U        2.7
# 976   Intel Core i5 6200U        2.3
#
# [977 rows x 17 columns]

# %%
laptop['cpu name'].unique()
# Out:
# array(['Intel Core i5', 'Intel Core i5 7200U', 'Intel Core i7',
#        'AMD A9-Series 9420', 'Intel Core i7 8550U', 'Intel Core i5 8250U',
#        'Intel Core i3 6006U', 'Intel Core M m3', 'Intel Core i7 7500U',
#        'Intel Core i3 7100U', 'Intel Atom x5-Z8350',
#        'Intel Core i5 7300HQ', 'AMD E-Series E2-9000e',
#        'Intel Core i7 8650U', 'Intel Atom x5-Z8300',
#        'AMD E-Series E2-6110', 'AMD A6-Series 9220',
#        'Intel Celeron Dual Core N3350', 'Intel Core i3 7130U',
#        'Intel Core i7 7700HQ', 'AMD Ryzen 1700',
#        'Intel Pentium Quad Core N4200', 'Intel Atom x5-Z8550',
#        'Intel Celeron Dual Core N3060', 'AMD FX 9830P',
#        'Intel Core i7 7560U', 'AMD E-Series 6110', 'Intel Core i5 6200U',
#        'Intel Core M 6Y75', 'Intel Core i5 7500U', 'Intel Core i7 6920HQ',
#        'Intel Core i5 7Y54', 'Intel Core i7 7820HK',
#        'Intel Xeon E3-1505M V6', 'Intel Core i7 6500U',
#        'AMD E-Series 9000e', 'AMD A10-Series A10-9620P',
#        'AMD A6-Series A6-9220', 'Intel Core i7 6600U',
#        'Intel Celeron Dual Core 3205U', 'Intel Core i7 7820HQ',
#        'AMD A10-Series 9600P', 'Intel Core i7 7600U',
#        'AMD A8-Series 7410', 'Intel Celeron Dual Core 3855U',
#        'Intel Pentium Quad Core N3710', 'AMD A12-Series 9720P',
#        'Intel Core i5 7300U', 'Intel Celeron Quad Core N3450',
#        'Intel Core i5 6440HQ', 'Intel Core i7 6820HQ', 'AMD Ryzen 1600',
#        'Intel Core i7 7Y75', 'Intel Core i5 7440HQ',
#        'Intel Core i7 7660U', 'Intel Core M m3-7Y30',
#        'Intel Core i5 7Y57', 'Intel Core i7 6700HQ',
#        'Intel Core i3 6100U', 'AMD A10-Series 9620P', 'AMD E-Series 7110',
#        'AMD A9-Series A9-9420', 'Intel Core i7 6820HK',
#        'Intel Core M 7Y30', 'Intel Xeon E3-1535M v6',
#        'Intel Celeron Quad Core N3160', 'Intel Core i5 6300U',
#        'AMD E-Series E2-9000', 'Intel Celeron Dual Core N3050',
#        'Intel Core M M3-6Y30', 'Intel Core i5 6300HQ',
#        'AMD A6-Series 7310', 'Intel Atom Z8350', 'Intel Xeon E3-1535M v5',
#        'Intel Core i5 6260U', 'Intel Pentium Dual Core N4200',
#        'Intel Celeron Quad Core N3710', 'Intel Core M',
#        'AMD A12-Series 9700P', 'Intel Pentium Dual Core 4405U',
#        'AMD A4-Series 7210', 'Intel Core i7 6560U',
#        'Intel Core M m7-6Y75', 'AMD FX 8800P', 'Intel Core M M7-6Y75'],
#       dtype=object)

# %%
laptop['cpu brand'] = laptop['cpu name'].str.rsplit(' ', n=0).str[0]

laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu   ram               storage  \
# 0           Intel Core i5 2.3GHz   8GB             128GB SSD
# 1           Intel Core i5 1.8GHz   8GB   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 3           Intel Core i7 2.7GHz  16GB             512GB SSD
# 4           Intel Core i5 3.1GHz   8GB             256GB SSD
# ..                           ...   ...                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32GB  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8GB  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4GB          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      weight        price resolution             screentype  touchscreen  \
# 0    1.37kg  11912523.48  2560x1600  IPSPanelRetinaDisplay          0.0
# 1    1.34kg   7993374.48   1440x900                    NaN          0.0
# 2    1.86kg   5112900.00  1920x1080                    NaN          0.0
# 3    1.83kg  22563005.40  2880x1800  IPSPanelRetinaDisplay          0.0
# 4    1.37kg  16037611.20  2560x1600  IPSPanelRetinaDisplay          0.0
# ..      ...          ...        ...                    ...          ...
# 972  4.42kg  24897600.00  1920x1080                    NaN          0.0
# 973  1.95kg  10492560.00  1920x1080                    NaN          0.0
# 974  2.73kg  18227710.80  1920x1080                    NaN          0.0
# 975  2.04kg   8705268.00  1920x1080               IPSPanel          0.0
# 976  1.70kg   8909784.00   1366x768                    NaN          0.0
#
#                  cpu name  cpu speed cpu brand
# 0           Intel Core i5        2.3     Intel
# 1           Intel Core i5        1.8     Intel
# 2     Intel Core i5 7200U        2.5     Intel
# 3           Intel Core i7        2.7     Intel
# 4           Intel Core i5        3.1     Intel
# ..                    ...        ...       ...
# 972  Intel Core i7 6700HQ        2.6     Intel
# 973   Intel Core i5 6200U        2.3     Intel
# 974  Intel Core i7 7700HQ        2.8     Intel
# 975   Intel Core i5 7200U        2.7     Intel
# 976   Intel Core i5 6200U        2.3     Intel
#
# [977 rows x 18 columns]

# %%
laptop['cpu brand'].value_counts()
# Out:
# Intel    929
# AMD       48
# Name: cpu brand, dtype: int64

# %%
laptop['ram'] = laptop['ram'].str.replace('GB', '')
laptop['ram'].astype('int64')
laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      weight        price resolution             screentype  touchscreen  \
# 0    1.37kg  11912523.48  2560x1600  IPSPanelRetinaDisplay          0.0
# 1    1.34kg   7993374.48   1440x900                    NaN          0.0
# 2    1.86kg   5112900.00  1920x1080                    NaN          0.0
# 3    1.83kg  22563005.40  2880x1800  IPSPanelRetinaDisplay          0.0
# 4    1.37kg  16037611.20  2560x1600  IPSPanelRetinaDisplay          0.0
# ..      ...          ...        ...                    ...          ...
# 972  4.42kg  24897600.00  1920x1080                    NaN          0.0
# 973  1.95kg  10492560.00  1920x1080                    NaN          0.0
# 974  2.73kg  18227710.80  1920x1080                    NaN          0.0
# 975  2.04kg   8705268.00  1920x1080               IPSPanel          0.0
# 976  1.70kg   8909784.00   1366x768                    NaN          0.0
#
#                  cpu name  cpu speed cpu brand
# 0           Intel Core i5        2.3     Intel
# 1           Intel Core i5        1.8     Intel
# 2     Intel Core i5 7200U        2.5     Intel
# 3           Intel Core i7        2.7     Intel
# 4           Intel Core i5        3.1     Intel
# ..                    ...        ...       ...
# 972  Intel Core i7 6700HQ        2.6     Intel
# 973   Intel Core i5 6200U        2.3     Intel
# 974  Intel Core i7 7700HQ        2.8     Intel
# 975   Intel Core i5 7200U        2.7     Intel
# 976   Intel Core i5 6200U        2.3     Intel
#
# [977 rows x 18 columns]

# %%
laptop['storage']
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 3                 512GB SSD
# 4                 256GB SSD
#                ...
# 972    256GB SSD +  1TB HDD
# 973               256GB SSD
# 974    256GB SSD +  1TB HDD
# 975    128GB SSD +  1TB HDD
# 976            508GB Hybrid
# Name: storage, Length: 977, dtype: object

# %%
laptop[['storage_1', 'storage_2']] = laptop['storage'].str.split(' + ', n=1, expand=True)

laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      weight        price resolution             screentype  touchscreen  \
# 0    1.37kg  11912523.48  2560x1600  IPSPanelRetinaDisplay          0.0
# 1    1.34kg   7993374.48   1440x900                    NaN          0.0
# 2    1.86kg   5112900.00  1920x1080                    NaN          0.0
# 3    1.83kg  22563005.40  2880x1800  IPSPanelRetinaDisplay          0.0
# 4    1.37kg  16037611.20  2560x1600  IPSPanelRetinaDisplay          0.0
# ..      ...          ...        ...                    ...          ...
# 972  4.42kg  24897600.00  1920x1080                    NaN          0.0
# 973  1.95kg  10492560.00  1920x1080                    NaN          0.0
# 974  2.73kg  18227710.80  1920x1080                    NaN          0.0
# 975  2.04kg   8705268.00  1920x1080               IPSPanel          0.0
# 976  1.70kg   8909784.00   1366x768                    NaN          0.0
#
#                  cpu name  cpu speed cpu brand            storage_1 storage_2
# 0           Intel Core i5        2.3     Intel            128GB SSD      None
# 1           Intel Core i5        1.8     Intel  128GB Flash Storage      None
# 2     Intel Core i5 7200U        2.5     Intel            256GB SSD      None
# 3           Intel Core i7        2.7     Intel            512GB SSD      None
# 4           Intel Core i5        3.1     Intel            256GB SSD      None
# ..                    ...        ...       ...                  ...       ...
# 972  Intel Core i7 6700HQ        2.6     Intel          256GB SSD +   1TB HDD
# 973   Intel Core i5 6200U        2.3     Intel            256GB SSD      None
# 974  Intel Core i7 7700HQ        2.8     Intel          256GB SSD +   1TB HDD
# 975   Intel Core i5 7200U        2.7     Intel          128GB SSD +   1TB HDD
# 976   Intel Core i5 6200U        2.3     Intel         508GB Hybrid      None
#
# [977 rows x 20 columns]

# %%
laptop['storage_1'] = laptop['storage_1'].str.replace('+', ' ')

laptop
# Out:
# C:\Users\axioo\AppData\Local\Temp\ipykernel_19804\3991093528.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   laptop['storage_1'] = laptop['storage_1'].str.replace('+', ' ')
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      weight        price resolution             screentype  touchscreen  \
# 0    1.37kg  11912523.48  2560x1600  IPSPanelRetinaDisplay          0.0
# 1    1.34kg   7993374.48   1440x900                    NaN          0.0
# 2    1.86kg   5112900.00  1920x1080                    NaN          0.0
# 3    1.83kg  22563005.40  2880x1800  IPSPanelRetinaDisplay          0.0
# 4    1.37kg  16037611.20  2560x1600  IPSPanelRetinaDisplay          0.0
# ..      ...          ...        ...                    ...          ...
# 972  4.42kg  24897600.00  1920x1080                    NaN          0.0
# 973  1.95kg  10492560.00  1920x1080                    NaN          0.0
# 974  2.73kg  18227710.80  1920x1080                    NaN          0.0
# 975  2.04kg   8705268.00  1920x1080               IPSPanel          0.0
# 976  1.70kg   8909784.00   1366x768                    NaN          0.0
#
#                  cpu name  cpu speed cpu brand            storage_1 storage_2
# 0           Intel Core i5        2.3     Intel            128GB SSD      None
# 1           Intel Core i5        1.8     Intel  128GB Flash Storage      None
# 2     Intel Core i5 7200U        2.5     Intel            256GB SSD      None
# 3           Intel Core i7        2.7     Intel            512GB SSD      None
# 4           Intel Core i5        3.1     Intel            256GB SSD      None
# ..                    ...        ...       ...                  ...       ...
# 972  Intel Core i7 6700HQ        2.6     Intel          256GB SSD     1TB HDD
# 973   Intel Core i5 6200U        2.3     Intel            256GB SSD      None
# 974  Intel Core i7 7700HQ        2.8     Intel          256GB SSD     1TB HDD
# 975   Intel Core i5 7200U        2.7     Intel          128GB SSD     1TB HDD
# 976   Intel Core i5 6200U        2.3     Intel         508GB Hybrid      None
#
# [977 rows x 20 columns]

# %%
laptop['storage_1']
# Out:
# 0                128GB SSD
# 1      128GB Flash Storage
# 2                256GB SSD
# 3                512GB SSD
# 4                256GB SSD
#               ...
# 972            256GB SSD
# 973              256GB SSD
# 974            256GB SSD
# 975            128GB SSD
# 976           508GB Hybrid
# Name: storage_1, Length: 977, dtype: object

# %%
laptop['storage_1'] = laptop['storage_1'].str.replace('1.0TB', '1TB', regex=True)
laptop['storage_1'] = laptop['storage_1'].str.replace('1TB', '1000GB')
laptop['storage_1'] = laptop['storage_1'].str.replace('2TB', '2000GB')
laptop['storage_1'] = laptop['storage_1'].str.replace("GB", "")
laptop['storage_1'].value_counts()
# Out:
# 256 SSD               318
# 1000 HDD              171
# 512 SSD                91
# 500 HDD                79
# 128 SSD                73
# 256 SSD                65
# 128 SSD                62
# 32 Flash Storage       29
# 512 SSD                17
# 2000 HDD               14
# 1000 SSD               11
# 64 Flash Storage        9
# 16 Flash Storage        6
# 32 SSD                  5
# 256 Flash Storage       5
# 128 Flash Storage       4
# 1 SSD                   4
# 1000 SSD                2
# 16 SSD                  2
# 8 SSD                   1
# 240 SSD                 1
# 128 HDD                 1
# 512 Flash Storage       1
# 1000 Hybrid             1
# 32 HDD                  1
# 1000 HDD                1
# 64 Flash Storage        1
# 64 SSD                  1
# 508 Hybrid              1
# Name: storage_1, dtype: int64

# %%
laptop[['storage_1', 'storage_1_type']] = laptop['storage_1'].str.split(' ', 1, expand=True)

laptop
# Out:
# C:\Users\axioo\AppData\Local\Temp\ipykernel_19804\4201828982.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptop[['storage_1', 'storage_1_type']] = laptop['storage_1'].str.split(' ', 1, expand=True)
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      ...        price  resolution             screentype touchscreen  \
# 0    ...  11912523.48   2560x1600  IPSPanelRetinaDisplay         0.0
# 1    ...   7993374.48    1440x900                    NaN         0.0
# 2    ...   5112900.00   1920x1080                    NaN         0.0
# 3    ...  22563005.40   2880x1800  IPSPanelRetinaDisplay         0.0
# 4    ...  16037611.20   2560x1600  IPSPanelRetinaDisplay         0.0
# ..   ...          ...         ...                    ...         ...
# 972  ...  24897600.00   1920x1080                    NaN         0.0
# 973  ...  10492560.00   1920x1080                    NaN         0.0
# 974  ...  18227710.80   1920x1080                    NaN         0.0
# 975  ...   8705268.00   1920x1080               IPSPanel         0.0
# 976  ...   8909784.00    1366x768                    NaN         0.0
#
#                  cpu name cpu speed  cpu brand storage_1 storage_2  \
# 0           Intel Core i5       2.3      Intel       128      None
# 1           Intel Core i5       1.8      Intel       128      None
# 2     Intel Core i5 7200U       2.5      Intel       256      None
# 3           Intel Core i7       2.7      Intel       512      None
# 4           Intel Core i5       3.1      Intel       256      None
# ..                    ...       ...        ...       ...       ...
# 972  Intel Core i7 6700HQ       2.6      Intel       256   1TB HDD
# 973   Intel Core i5 6200U       2.3      Intel       256      None
# 974  Intel Core i7 7700HQ       2.8      Intel       256   1TB HDD
# 975   Intel Core i5 7200U       2.7      Intel       128   1TB HDD
# 976   Intel Core i5 6200U       2.3      Intel       508      None
#
#     storage_1_type
# 0              SSD
# 1    Flash Storage
# 2              SSD
# 3              SSD
# 4              SSD
# ..             ...
# 972          SSD
# 973            SSD
# 974          SSD
# 975          SSD
# 976         Hybrid
#
# [977 rows x 21 columns]

# %%
laptop['storage_2'] = laptop['storage_2'].str.replace('1.0TB', '1TB', regex=True)
laptop['storage_2'] = laptop['storage_2'].str.replace('1TB', '1000GB')
laptop['storage_2'] = laptop['storage_2'].str.replace('2TB', '2000GB')
laptop['storage_2'] = laptop['storage_2'].str.replace("GB", "")

laptop[['storage_2', 'storage_2_type']] = laptop['storage_2'].str.split(' ', 1, expand=True)

laptop
# Out:
# C:\Users\axioo\AppData\Local\Temp\ipykernel_19804\467146925.py:6: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   laptop[['storage_2', 'storage_2_type']] = laptop['storage_2'].str.split(' ', 1, expand=True)
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      ... resolution             screentype touchscreen              cpu name  \
# 0    ...  2560x1600  IPSPanelRetinaDisplay         0.0         Intel Core i5
# 1    ...   1440x900                    NaN         0.0         Intel Core i5
# 2    ...  1920x1080                    NaN         0.0   Intel Core i5 7200U
# 3    ...  2880x1800  IPSPanelRetinaDisplay         0.0         Intel Core i7
# 4    ...  2560x1600  IPSPanelRetinaDisplay         0.0         Intel Core i5
# ..   ...        ...                    ...         ...                   ...
# 972  ...  1920x1080                    NaN         0.0  Intel Core i7 6700HQ
# 973  ...  1920x1080                    NaN         0.0   Intel Core i5 6200U
# 974  ...  1920x1080                    NaN         0.0  Intel Core i7 7700HQ
# 975  ...  1920x1080               IPSPanel         0.0   Intel Core i5 7200U
# 976  ...   1366x768                    NaN         0.0   Intel Core i5 6200U
#
#      cpu speed cpu brand  storage_1 storage_2 storage_1_type storage_2_type
# 0          2.3     Intel        128      None            SSD           None
# 1          1.8     Intel        128      None  Flash Storage           None
# 2          2.5     Intel        256      None            SSD           None
# 3          2.7     Intel        512      None            SSD           None
# 4          3.1     Intel        256      None            SSD           None
# ..         ...       ...        ...       ...            ...            ...
# 972        2.6     Intel        256      1000          SSD              HDD
# 973        2.3     Intel        256      None            SSD           None
# 974        2.8     Intel        256      1000          SSD              HDD
# 975        2.7     Intel        128      1000          SSD              HDD
# 976        2.3     Intel        508      None         Hybrid           None
#
# [977 rows x 22 columns]

# %%
laptop['storage_1'] = laptop['storage_1'].astype('float')
laptop['storage_2'] = laptop['storage_2'].astype('float')

laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      ... resolution             screentype touchscreen              cpu name  \
# 0    ...  2560x1600  IPSPanelRetinaDisplay         0.0         Intel Core i5
# 1    ...   1440x900                    NaN         0.0         Intel Core i5
# 2    ...  1920x1080                    NaN         0.0   Intel Core i5 7200U
# 3    ...  2880x1800  IPSPanelRetinaDisplay         0.0         Intel Core i7
# 4    ...  2560x1600  IPSPanelRetinaDisplay         0.0         Intel Core i5
# ..   ...        ...                    ...         ...                   ...
# 972  ...  1920x1080                    NaN         0.0  Intel Core i7 6700HQ
# 973  ...  1920x1080                    NaN         0.0   Intel Core i5 6200U
# 974  ...  1920x1080                    NaN         0.0  Intel Core i7 7700HQ
# 975  ...  1920x1080               IPSPanel         0.0   Intel Core i5 7200U
# 976  ...   1366x768                    NaN         0.0   Intel Core i5 6200U
#
#      cpu speed cpu brand  storage_1 storage_2  storage_1_type  storage_2_type
# 0          2.3     Intel      128.0       NaN             SSD            None
# 1          1.8     Intel      128.0       NaN   Flash Storage            None
# 2          2.5     Intel      256.0       NaN             SSD            None
# 3          2.7     Intel      512.0       NaN             SSD            None
# 4          3.1     Intel      256.0       NaN             SSD            None
# ..         ...       ...        ...       ...             ...             ...
# 972        2.6     Intel      256.0    1000.0           SSD               HDD
# 973        2.3     Intel      256.0       NaN             SSD            None
# 974        2.8     Intel      256.0    1000.0           SSD               HDD
# 975        2.7     Intel      128.0    1000.0           SSD               HDD
# 976        2.3     Intel      508.0       NaN          Hybrid            None
#
# [977 rows x 22 columns]

# %%
laptop['storage_2'] = laptop['storage_2'].fillna(0.0)
laptop['storage_2_type'] = laptop['storage_2_type'].fillna(np.nan)
laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      ... resolution             screentype touchscreen              cpu name  \
# 0    ...  2560x1600  IPSPanelRetinaDisplay         0.0         Intel Core i5
# 1    ...   1440x900                    NaN         0.0         Intel Core i5
# 2    ...  1920x1080                    NaN         0.0   Intel Core i5 7200U
# 3    ...  2880x1800  IPSPanelRetinaDisplay         0.0         Intel Core i7
# 4    ...  2560x1600  IPSPanelRetinaDisplay         0.0         Intel Core i5
# ..   ...        ...                    ...         ...                   ...
# 972  ...  1920x1080                    NaN         0.0  Intel Core i7 6700HQ
# 973  ...  1920x1080                    NaN         0.0   Intel Core i5 6200U
# 974  ...  1920x1080                    NaN         0.0  Intel Core i7 7700HQ
# 975  ...  1920x1080               IPSPanel         0.0   Intel Core i5 7200U
# 976  ...   1366x768                    NaN         0.0   Intel Core i5 6200U
#
#      cpu speed cpu brand  storage_1 storage_2  storage_1_type  storage_2_type
# 0          2.3     Intel      128.0       0.0             SSD             NaN
# 1          1.8     Intel      128.0       0.0   Flash Storage             NaN
# 2          2.5     Intel      256.0       0.0             SSD             NaN
# 3          2.7     Intel      512.0       0.0             SSD             NaN
# 4          3.1     Intel      256.0       0.0             SSD             NaN
# ..         ...       ...        ...       ...             ...             ...
# 972        2.6     Intel      256.0    1000.0           SSD               HDD
# 973        2.3     Intel      256.0       0.0             SSD             NaN
# 974        2.8     Intel      256.0    1000.0           SSD               HDD
# 975        2.7     Intel      128.0    1000.0           SSD               HDD
# 976        2.3     Intel      508.0       0.0          Hybrid             NaN
#
# [977 rows x 22 columns]

# %%
laptop['gpu name'] = laptop['gpu'].str.extract(r'^(\w+)')
laptop['gpu name'].value_counts()
# Out:
# Intel     525
# Nvidia    310
# AMD       142
# Name: gpu name, dtype: int64

# %%
laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                      NaN
# 1          Intel HD Graphics 6000            macOS                      NaN
# 2           Intel HD Graphics 620            No OS                      NaN
# 3              AMD Radeon Pro 455            macOS                      NaN
# 4    Intel Iris Plus Graphics 650            macOS                      NaN
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows                       10
# 973         Intel HD Graphics 520          Windows                       10
# 974       Nvidia GeForce GTX 1060          Windows                       10
# 975          Nvidia GeForce 930MX          Windows                       10
# 976         Intel HD Graphics 520          Windows                        7
#
#      ...             screentype  touchscreen              cpu name cpu speed  \
# 0    ...  IPSPanelRetinaDisplay          0.0         Intel Core i5       2.3
# 1    ...                    NaN          0.0         Intel Core i5       1.8
# 2    ...                    NaN          0.0   Intel Core i5 7200U       2.5
# 3    ...  IPSPanelRetinaDisplay          0.0         Intel Core i7       2.7
# 4    ...  IPSPanelRetinaDisplay          0.0         Intel Core i5       3.1
# ..   ...                    ...          ...                   ...       ...
# 972  ...                    NaN          0.0  Intel Core i7 6700HQ       2.6
# 973  ...                    NaN          0.0   Intel Core i5 6200U       2.3
# 974  ...                    NaN          0.0  Intel Core i7 7700HQ       2.8
# 975  ...               IPSPanel          0.0   Intel Core i5 7200U       2.7
# 976  ...                    NaN          0.0   Intel Core i5 6200U       2.3
#
#      cpu brand storage_1  storage_2 storage_1_type  storage_2_type  gpu name
# 0        Intel     128.0        0.0            SSD             NaN     Intel
# 1        Intel     128.0        0.0  Flash Storage             NaN     Intel
# 2        Intel     256.0        0.0            SSD             NaN     Intel
# 3        Intel     512.0        0.0            SSD             NaN       AMD
# 4        Intel     256.0        0.0            SSD             NaN     Intel
# ..         ...       ...        ...            ...             ...       ...
# 972      Intel     256.0     1000.0          SSD               HDD    Nvidia
# 973      Intel     256.0        0.0            SSD             NaN     Intel
# 974      Intel     256.0     1000.0          SSD               HDD    Nvidia
# 975      Intel     128.0     1000.0          SSD               HDD    Nvidia
# 976      Intel     508.0        0.0         Hybrid             NaN     Intel
#
# [977 rows x 23 columns]

# %%
laptop['operating system version'].fillna('', inplace=True)

# %%
laptop['os version'] = laptop['operating system'] + ' ' + laptop['operating system version']
laptop['operating system version'] = laptop['os version']
laptop
# Out:
#     manufacturer       model name   category screen size  \
# 0          Apple      MacBook Pro  Ultrabook        13.3
# 1          Apple      Macbook Air  Ultrabook        13.3
# 2             HP           250 G6   Notebook        15.6
# 3          Apple      MacBook Pro  Ultrabook        15.4
# 4          Apple      MacBook Pro  Ultrabook        13.3
# ..           ...              ...        ...         ...
# 972         Dell     Alienware 17     Gaming        17.3
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0
# 974         Asus        Rog Strix     Gaming        17.3
# 975           HP      Probook 450   Notebook        15.6
# 976       Lenovo    ThinkPad T460   Notebook        14.0
#
#                              cpu ram               storage  \
# 0           Intel Core i5 2.3GHz   8             128GB SSD
# 1           Intel Core i5 1.8GHz   8   128GB Flash Storage
# 2     Intel Core i5 7200U 2.5GHz   8             256GB SSD
# 3           Intel Core i7 2.7GHz  16             512GB SSD
# 4           Intel Core i5 3.1GHz   8             256GB SSD
# ..                           ...  ..                   ...
# 972  Intel Core i7 6700HQ 2.6GHz  32  256GB SSD +  1TB HDD
# 973   Intel Core i5 6200U 2.3GHz   8             256GB SSD
# 974  Intel Core i7 7700HQ 2.8GHz  16  256GB SSD +  1TB HDD
# 975  Intel Core i5 7200U 2.70GHz   8  128GB SSD +  1TB HDD
# 976   Intel Core i5 6200U 2.3GHz   4          508GB Hybrid
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                   macOS
# 1          Intel HD Graphics 6000            macOS                   macOS
# 2           Intel HD Graphics 620            No OS                   No OS
# 3              AMD Radeon Pro 455            macOS                   macOS
# 4    Intel Iris Plus Graphics 650            macOS                   macOS
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows               Windows 10
# 973         Intel HD Graphics 520          Windows               Windows 10
# 974       Nvidia GeForce GTX 1060          Windows               Windows 10
# 975          Nvidia GeForce 930MX          Windows               Windows 10
# 976         Intel HD Graphics 520          Windows                Windows 7
#
#      ... touchscreen              cpu name cpu speed cpu brand  storage_1  \
# 0    ...         0.0         Intel Core i5       2.3     Intel      128.0
# 1    ...         0.0         Intel Core i5       1.8     Intel      128.0
# 2    ...         0.0   Intel Core i5 7200U       2.5     Intel      256.0
# 3    ...         0.0         Intel Core i7       2.7     Intel      512.0
# 4    ...         0.0         Intel Core i5       3.1     Intel      256.0
# ..   ...         ...                   ...       ...       ...        ...
# 972  ...         0.0  Intel Core i7 6700HQ       2.6     Intel      256.0
# 973  ...         0.0   Intel Core i5 6200U       2.3     Intel      256.0
# 974  ...         0.0  Intel Core i7 7700HQ       2.8     Intel      256.0
# 975  ...         0.0   Intel Core i5 7200U       2.7     Intel      128.0
# 976  ...         0.0   Intel Core i5 6200U       2.3     Intel      508.0
#
#     storage_2  storage_1_type storage_2_type  gpu name  os version
# 0         0.0             SSD            NaN     Intel      macOS
# 1         0.0   Flash Storage            NaN     Intel      macOS
# 2         0.0             SSD            NaN     Intel      No OS
# 3         0.0             SSD            NaN       AMD      macOS
# 4         0.0             SSD            NaN     Intel      macOS
# ..        ...             ...            ...       ...         ...
# 972    1000.0           SSD              HDD    Nvidia  Windows 10
# 973       0.0             SSD            NaN     Intel  Windows 10
# 974    1000.0           SSD              HDD    Nvidia  Windows 10
# 975    1000.0           SSD              HDD    Nvidia  Windows 10
# 976       0.0          Hybrid            NaN     Intel   Windows 7
#
# [977 rows x 24 columns]

# %%
laptop['weight'] = laptop['weight'].str.replace('kg', '')
laptop ['weight'] = laptop['weight'].astype('float')

# %%
laptop.columns
# Out:
# Index(['manufacturer', 'model name', 'category', 'screen size', 'cpu', 'ram',
#        'storage', 'gpu', 'operating system', 'operating system version',
#        'weight', 'price', 'resolution', 'screentype', 'touchscreen',
#        'cpu name', 'cpu speed', 'cpu brand', 'storage_1', 'storage_2',
#        'storage_1_type', 'storage_2_type', 'gpu name', 'os version'],
#       dtype='object')

# %%
laptop = laptop.drop(['cpu', 'storage', 'cpu', 'os version'], axis = 1)

laptop
# Out:
#     manufacturer       model name   category screen size ram  \
# 0          Apple      MacBook Pro  Ultrabook        13.3   8
# 1          Apple      Macbook Air  Ultrabook        13.3   8
# 2             HP           250 G6   Notebook        15.6   8
# 3          Apple      MacBook Pro  Ultrabook        15.4  16
# 4          Apple      MacBook Pro  Ultrabook        13.3   8
# ..           ...              ...        ...         ...  ..
# 972         Dell     Alienware 17     Gaming        17.3  32
# 973      Toshiba  Tecra A40-C-1DF   Notebook        14.0   8
# 974         Asus        Rog Strix     Gaming        17.3  16
# 975           HP      Probook 450   Notebook        15.6   8
# 976       Lenovo    ThinkPad T460   Notebook        14.0   4
#
#                               gpu operating system operating system version  \
# 0    Intel Iris Plus Graphics 640            macOS                   macOS
# 1          Intel HD Graphics 6000            macOS                   macOS
# 2           Intel HD Graphics 620            No OS                   No OS
# 3              AMD Radeon Pro 455            macOS                   macOS
# 4    Intel Iris Plus Graphics 650            macOS                   macOS
# ..                            ...              ...                      ...
# 972       Nvidia GeForce GTX 1070          Windows               Windows 10
# 973         Intel HD Graphics 520          Windows               Windows 10
# 974       Nvidia GeForce GTX 1060          Windows               Windows 10
# 975          Nvidia GeForce 930MX          Windows               Windows 10
# 976         Intel HD Graphics 520          Windows                Windows 7
#
#      weight        price  ...             screentype touchscreen  \
# 0      1.37  11912523.48  ...  IPSPanelRetinaDisplay         0.0
# 1      1.34   7993374.48  ...                    NaN         0.0
# 2      1.86   5112900.00  ...                    NaN         0.0
# 3      1.83  22563005.40  ...  IPSPanelRetinaDisplay         0.0
# 4      1.37  16037611.20  ...  IPSPanelRetinaDisplay         0.0
# ..      ...          ...  ...                    ...         ...
# 972    4.42  24897600.00  ...                    NaN         0.0
# 973    1.95  10492560.00  ...                    NaN         0.0
# 974    2.73  18227710.80  ...                    NaN         0.0
# 975    2.04   8705268.00  ...               IPSPanel         0.0
# 976    1.70   8909784.00  ...                    NaN         0.0
#
#                  cpu name cpu speed  cpu brand storage_1  storage_2  \
# 0           Intel Core i5       2.3      Intel     128.0        0.0
# 1           Intel Core i5       1.8      Intel     128.0        0.0
# 2     Intel Core i5 7200U       2.5      Intel     256.0        0.0
# 3           Intel Core i7       2.7      Intel     512.0        0.0
# 4           Intel Core i5       3.1      Intel     256.0        0.0
# ..                    ...       ...        ...       ...        ...
# 972  Intel Core i7 6700HQ       2.6      Intel     256.0     1000.0
# 973   Intel Core i5 6200U       2.3      Intel     256.0        0.0
# 974  Intel Core i7 7700HQ       2.8      Intel     256.0     1000.0
# 975   Intel Core i5 7200U       2.7      Intel     128.0     1000.0
# 976   Intel Core i5 6200U       2.3      Intel     508.0        0.0
#
#      storage_1_type storage_2_type gpu name
# 0               SSD            NaN    Intel
# 1     Flash Storage            NaN    Intel
# 2               SSD            NaN    Intel
# 3               SSD            NaN      AMD
# 4               SSD            NaN    Intel
# ..              ...            ...      ...
# 972           SSD              HDD   Nvidia
# 973             SSD            NaN    Intel
# 974           SSD              HDD   Nvidia
# 975           SSD              HDD   Nvidia
# 976          Hybrid            NaN    Intel
#
# [977 rows x 21 columns]

# %%
laptop = laptop.rename(columns = {'manufacturer': 'company', 'model name': 'product', 'screen size': 'screen(pixel)', 'ram': 'ram(GB)', 'weight': 'weigth(kg)', 'operating system': 'os', 'operating system version': 'os_version', 'cpu name': 'cpu_name', 'cpu speed': 'cpu_speed(GHz)', 'cpu brand': 'cpu_brand', 'storage_1': 'storage_1(GB)', 'storage_2': 'storage_2(GB)', 'gpu name': 'gpu_name'})

laptop.columns
# Out:
# Index(['company', 'product', 'category', 'screen(pixel)', 'ram(GB)', 'gpu',
#        'os', 'os_version', 'weigth(kg)', 'price', 'resolution', 'screentype',
#        'touchscreen', 'cpu_name', 'cpu_speed(GHz)', 'cpu_brand',
#        'storage_1(GB)', 'storage_2(GB)', 'storage_1_type', 'storage_2_type',
#        'gpu_name'],
#       dtype='object')

# %%
laptop
# Out:
#      company          product   category screen(pixel) ram(GB)  \
# 0      Apple      MacBook Pro  Ultrabook          13.3       8
# 1      Apple      Macbook Air  Ultrabook          13.3       8
# 2         HP           250 G6   Notebook          15.6       8
# 3      Apple      MacBook Pro  Ultrabook          15.4      16
# 4      Apple      MacBook Pro  Ultrabook          13.3       8
# ..       ...              ...        ...           ...     ...
# 972     Dell     Alienware 17     Gaming          17.3      32
# 973  Toshiba  Tecra A40-C-1DF   Notebook          14.0       8
# 974     Asus        Rog Strix     Gaming          17.3      16
# 975       HP      Probook 450   Notebook          15.6       8
# 976   Lenovo    ThinkPad T460   Notebook          14.0       4
#
#                               gpu       os  os_version  weigth(kg)  \
# 0    Intel Iris Plus Graphics 640    macOS      macOS         1.37
# 1          Intel HD Graphics 6000    macOS      macOS         1.34
# 2           Intel HD Graphics 620    No OS      No OS         1.86
# 3              AMD Radeon Pro 455    macOS      macOS         1.83
# 4    Intel Iris Plus Graphics 650    macOS      macOS         1.37
# ..                            ...      ...         ...         ...
# 972       Nvidia GeForce GTX 1070  Windows  Windows 10        4.42
# 973         Intel HD Graphics 520  Windows  Windows 10        1.95
# 974       Nvidia GeForce GTX 1060  Windows  Windows 10        2.73
# 975          Nvidia GeForce 930MX  Windows  Windows 10        2.04
# 976         Intel HD Graphics 520  Windows   Windows 7        1.70
#
#            price  ...             screentype touchscreen  \
# 0    11912523.48  ...  IPSPanelRetinaDisplay         0.0
# 1     7993374.48  ...                    NaN         0.0
# 2     5112900.00  ...                    NaN         0.0
# 3    22563005.40  ...  IPSPanelRetinaDisplay         0.0
# 4    16037611.20  ...  IPSPanelRetinaDisplay         0.0
# ..           ...  ...                    ...         ...
# 972  24897600.00  ...                    NaN         0.0
# 973  10492560.00  ...                    NaN         0.0
# 974  18227710.80  ...                    NaN         0.0
# 975   8705268.00  ...               IPSPanel         0.0
# 976   8909784.00  ...                    NaN         0.0
#
#                  cpu_name cpu_speed(GHz)  cpu_brand storage_1(GB)  \
# 0           Intel Core i5            2.3      Intel         128.0
# 1           Intel Core i5            1.8      Intel         128.0
# 2     Intel Core i5 7200U            2.5      Intel         256.0
# 3           Intel Core i7            2.7      Intel         512.0
# 4           Intel Core i5            3.1      Intel         256.0
# ..                    ...            ...        ...           ...
# 972  Intel Core i7 6700HQ            2.6      Intel         256.0
# 973   Intel Core i5 6200U            2.3      Intel         256.0
# 974  Intel Core i7 7700HQ            2.8      Intel         256.0
# 975   Intel Core i5 7200U            2.7      Intel         128.0
# 976   Intel Core i5 6200U            2.3      Intel         508.0
#
#      storage_2(GB)  storage_1_type storage_2_type gpu_name
# 0              0.0             SSD            NaN    Intel
# 1              0.0   Flash Storage            NaN    Intel
# 2              0.0             SSD            NaN    Intel
# 3              0.0             SSD            NaN      AMD
# 4              0.0             SSD            NaN    Intel
# ..             ...             ...            ...      ...
# 972         1000.0           SSD              HDD   Nvidia
# 973            0.0             SSD            NaN    Intel
# 974         1000.0           SSD              HDD   Nvidia
# 975         1000.0           SSD              HDD   Nvidia
# 976            0.0          Hybrid            NaN    Intel
#
# [977 rows x 21 columns]

# %%
laptop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   company         977 non-null    object
#  1   product         977 non-null    object
#  2   category        977 non-null    object
#  3   screen(pixel)   977 non-null    object
#  4   ram(GB)         977 non-null    object
#  5   gpu             977 non-null    object
#  6   os              977 non-null    object
#  7   os_version      977 non-null    object
#  8   weigth(kg)      977 non-null    float64
#  9   price           977 non-null    float64
#  10  resolution      977 non-null    object
#  11  screentype      280 non-null    object
#  12  touchscreen     977 non-null    float64
#  13  cpu_name        977 non-null    object
#  14  cpu_speed(GHz)  977 non-null    float64
#  15  cpu_brand       977 non-null    object
#  16  storage_1(GB)   977 non-null    float64
#  17  storage_2(GB)   977 non-null    float64
#  18  storage_1_type  977 non-null    object
#  19  storage_2_type  159 non-null    object
#  20  gpu_name        977 non-null    object
# dtypes: float64(6), object(15)
# memory usage: 160.4+ KB

# %%
laptop['ram(GB)'] = laptop['ram(GB)'].astype('int')

laptop.describe()
# Out:
#           ram(GB)  weigth(kg)         price  touchscreen  cpu_speed(GHz)  \
# count  977.000000  977.000000  9.770000e+02   977.000000      977.000000
# mean     8.528147    2.039128  1.001899e+07     0.144319        2.284033
# std      4.997487    0.666009  6.306430e+06     0.351593        0.523576
# min      2.000000    0.690000  1.706375e+06     0.000000        0.900000
# 25%      4.000000    1.500000  5.326308e+06     0.000000        1.800000
# 50%      8.000000    2.020000  8.527428e+06     0.000000        2.500000
# 75%      8.000000    2.300000  1.311570e+07     0.000000        2.700000
# max     32.000000    4.700000  5.423231e+07     1.000000        3.600000
#
#        storage_1(GB)  storage_2(GB)
# count     977.000000     977.000000
# mean      439.373593     173.776868
# std       364.729684     413.903988
# min         1.000000       0.000000
# 25%       256.000000       0.000000
# 50%       256.000000       0.000000
# 75%       512.000000       0.000000
# max      2000.000000    2000.000000

# %%
laptop.to_csv('laptop_clean.csv', index=False)
